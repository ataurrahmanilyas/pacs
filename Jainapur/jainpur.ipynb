# %%
import warnings
import pandas as pd

# Suppress specific warnings
warnings.filterwarnings("ignore", message="Print area cannot be set to Defined name")

excel_file = 'PKPS JAINAPUR complete data.xlsx';

xls = pd.ExcelFile(excel_file)
sheet_names = xls.sheet_names
print(sheet_names);
# Out:
# ['Membership Details', 'Land_Details', 'Personal Loan', 'Cash Credit Loan', 'Mortigage Loan', 'MT & LT loan', 'Vehicle Loan', 'FD Loan', 'KCC Loan', 'Saving Deposits', 'Fixed Deposite', 'Recurring Deposit', 'Collateral Details', 'Transaction Details', 'Pigmy Deposits', 'Agent Details']

# %%
excel_file = 'PKPS JAINAPUR complete data.xlsx';
all_sheets = pd.read_excel(excel_file, sheet_name=None)

# Creating a DataFrame for each sheet
dataframes = {sheet: pd.DataFrame(data) for sheet, data in all_sheets.items()}

# Displaying the first few rows of each DataFrame
for sheet_name, df in dataframes.items():
    print(f"Sheet: {sheet_name}")
    print(df.head())
# Out:
# Sheet: Membership Details
#   CUSTOMER TYPE MEMBER TYPE  ADMISSION NO.       SURNAME MEMBER NAME GENDER  \
# 0        Member      A-Type              6        BHAKRE    KALLAPPA   Male
# 1        Member      A-Type              8         PATIL      MARUTI   Male
# 2        Member      A-Type             10          KHAD       ASHOK   Male
# 3        Member      A-Type             12  KELAGINAMANI       SANJU   Male
# 4        Member      A-Type             14     LAXMANGOL     SHANKAR   Male
#
#    SHARE BALANCE                         VILLAGE  LEDGER FOLIO NO.  \
# 0           3354   AT: JAINAPUR PO: JAINAPUR TQ:               NaN
# 1            800   AT: JAINAPUR PO: JAINAPUR TQ:               NaN
# 2           2800  AT: TORANAHALLI PO: TORANAHALL               NaN
# 3            591   AT: JAINAPUR PO: JAINAPUR TQ:               NaN
# 4           1229   AT: JAINAPUR PO: JAINAPUR TQ:               NaN
#
# ...
